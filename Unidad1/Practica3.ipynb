# %% [markdown]
# <a href="https://colab.research.google.com/github/24041180/Probabilidad-y-estadistica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1
#
# Practica 3. Maximo, mínimo, rango y dispersión de datos
#
# Alumna: Hernandez Cabral Luis Angel

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [92.37, 63.72, 78.48, 69.55, 81.4, 77.8, 99.28, 52.94, 79.17, 98.23, 53.13, 80.48, 58.83, 66.91, 80.53, 82.93, 77.56, 85.65, 93.84, 53.74, 88.86, 99.03, 60.13, 89.81, 69.57, 60.35, 64.92, 96.78, 50.42, 76.06, 79.66, 80.69, 83.07, 56.78, 72.9, 88.98, 91.69, 86.91, 64.05, 96.85, 70.08, 53.85, 87.69, 92.78, 85.68, 75.28, 50.35, 58.93, 59.71, 52.41, 60.39, 86.11, 72.67, 65.71, 84.76, 93.04, 75.01, 55.56, 56.61, 58.17, 77.74, 89.09, 77.35, 77.14, 64.88, 50.81, 98.15, 87.64, 89.12, 72.59, 58.25, 97.17, 75.6, 60.91, 53.4, 51.04, 93.57, 91.95, 83.91, 67.56, 50.7, 71.95, 99.08, 62.74, 84.95, 66.25, 83.98, 68.41, 94.07, 94.88, 81.13, 58.03, 83.02, 82.88, 65.5, 83.82, 75.72, 73.67, 64.55, 87.79]

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio)
print (fabrica2)
# Out:
# [98.78, 69.57, 58.08, 67.2, 86.3, 72.37, 93.53, 66.52, 98.3, 75.49, 88.21, 63.86, 63.01, 59.2, 51.84, 80.38, 53.12, 58.88, 95.23, 51.08, 63.48, 54.75, 57.14, 50.22, 80.43, 94.02, 62.98, 69.49, 89.94, 93.13, 97.66, 59.59, 83.11, 73.15, 84.47, 82.67, 97.24, 77.14, 75.74, 58.13, 88.47, 51.41, 90.76, 95.51, 67.28, 58.09, 97.04, 78.54, 77.88, 85.88, 78.79, 88.64, 95.29, 87.43, 99.3, 89.78, 69.49, 50.84, 93.68, 99.35, 82.72, 51.12, 51.01, 90.17, 84.81, 76.81, 76.02, 53.48, 55.71, 88.79, 65.25, 57.79, 94.7, 65.09, 85.76, 77.83, 56.58, 98.48, 55.03, 55.13, 64.83, 87.03, 67.21, 70.81, 53.85, 55.91, 70.38, 63.39, 57.0, 91.87, 68.76, 55.13, 60.42, 62.87, 82.98, 86.53, 96.69, 86.35, 53.29, 62.24]

# %%
# Maximo, mínimo y rango
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1-minimo1
media1 =mean(fabrica1)
mediana1= median(fabrica1)
moda1 = mode(fabrica1)

print( "Estadistica descriptiva de la fabrica 1 \n", "Media =", media1,
      "\n Mediana = ", mediana1, "\n Moda = ", moda1, "\n Maximo = ", maximo1,
      "\n Minimo = ", minimo1, "\n Rango = ", rango1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 75.2983
#  Mediana =  77.245
#  Moda =  92.37
#  Maximo =  99.28
#  Minimo =  50.35
#  Rango =  48.93

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2-minimo2
media2=mean(fabrica2)
mediana2= median(fabrica2)
moda2 = mode(fabrica2)

print( "Estadistica descriptiva de la fabrica 2 \n", "Media =", media2,
      "\n Mediana = ", mediana2, "\n Moda = ", moda2, "\n Maximo = ", maximo2,
      "\n Minimo = ", minimo2, "\n Rango = ", rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  Media = 74.187
#  Mediana =  74.32
#  Moda =  69.49
#  Maximo =  99.35
#  Minimo =  50.22
#  Rango =  49.129999999999995

# %%
#  dispersion de los datos
desviacion_estandar_fabrica1 =stdev(fabrica1)
print (desviacion_estandar_fabrica1)
# Out:
# 14.45707670235507

# %%
desviacion_estandar_fabrica2 =stdev(fabrica2)
print (desviacion_estandar_fabrica2)
# Out:
# 15.62678647564993

# %%
plt.figure(figsize= (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color = 'b', edgecolor = "black")
plt.axvline(media1, color= 'b', linestyle='dashed', linewidth=2, label=f'Media = {media1:.2f}')
plt.axvline(mediana1, color= 'r', linestyle='dashed', linewidth=2, label=f'Mediana = {mediana1:.2f}')
plt.axvline(moda1, color= 'y', linestyle='dashed', linewidth=2, label=f'Moda = {moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color = "black", linestyle= 'dashed',
           linewidth= 2, label=f'Desv. Estandar = {desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color = "black", linestyle= 'dashed',
           linewidth= 2)
plt.xlabel ('Valor')
plt.ylabel(' Frecuencia ')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color = 'b', edgecolor = "black")
plt.axvline(media2, color= 'b', linestyle='dashed', linewidth=2, label=f'Media = {media2:.2f}')
plt.axvline(mediana2, color= 'r', linestyle='dashed', linewidth=2, label=f'Mediana = {mediana2:.2f}')
plt.axvline(moda2, color= 'y', linestyle='dashed', linewidth=2, label=f'Moda = {moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color = "black", linestyle= 'dashed',
           linewidth= 2, label=f'Desv. Estandar = {desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color = "black", linestyle= 'dashed',
           linewidth= 2)
plt.xlabel (' Valor')
plt.ylabel(' Frecuencia ')
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
# Densidad
import seaborn as sns

# %%
# La densidad gráfica es una forma de visualizar la distribución de datos en
 # un intervalo o período de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.
sns.histplot(x = fabrica1, kde= True, kde_kws={'bw_adjust': 0.5 }, bins= 10)
# Out:
# <Axes: ylabel='Count'>
